# %% [markdown]
# # Imports

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Constanten

# %%
CWD = Path(".").absolute()
DATA_DIR = CWD / "data"

# %% [markdown]
# # Data inladen

# %%
df_ruw = pd.read_csv(DATA_DIR / "dataset_huizen.csv")
df_ruw.head()
# Out:
#     id            thumbnail_url  \
# 0  1.0  157/297/564_720x480.jpg
# 1  1.1  156/951/932_720x480.jpg
# 2  1.2  156/892/483_720x480.jpg
# 3  1.3  156/721/454_720x480.jpg
# 4  1.4  156/557/658_720x480.jpg
#
#                                                  url         address1  \
# 0  koop/verkocht/rhenen/huis-42770620-cuneraweg-2...      Cuneraweg 2
# 1  koop/verkocht/utrecht/huis-42760179-knopstraat...     Knopstraat 8
# 2  koop/verkocht/stadskanaal/huis-42769415-bakboo...      Bakboord 35
# 3  koop/verkocht/enschede/huis-88118354-salviastr...  Salviastraat 45
# 4  koop/verkocht/bleiswijk/huis-88114139-emmastra...    Emmastraat 29
#
#               address2             price                  spatial_info  \
# 0       3911 RN Rhenen  € 1.200.000 k.k.  269 m² / 5.120 m²\n10 kamers
# 1      3551 ET Utrecht    € 550.000 k.k.      112 m² / 77 m²\n5 kamers
# 2  9501 JZ Stadskanaal    € 339.000 k.k.     139 m² / 465 m²\n5 kamers
# 3     7531 VX Enschede    € 245.000 k.k.     102 m² / 141 m²\n4 kamers
# 4    2665 CR Bleiswijk    € 320.000 k.k.      71 m² / 143 m²\n5 kamers
#
#               realtor_name                                        realtor_url  \
# 0      Sanders Makelaardij        makelaars/ochten/18172-sanders-makelaardij/
# 1       Morgen Makelaardij        makelaars/utrecht/17506-morgen-makelaardij/
# 2     Van Beilen Makelaars   makelaars/stadskanaal/9216-van-beilen-makelaars/
# 3         Alex Makelaardij         makelaars/enschede/81454-alex-makelaardij/
# 4  Karin de Jong makelaars  makelaars/bleiswijk/63638-karin-de-jong-makela...
#
#      address1_deep                               address2_deep  \
# 0      Cuneraweg 2                   3911 RN Rhenen Binnenveld
# 1     Knopstraat 8  3551 ET Utrecht 2e Daalsebuurt en omgeving
# 2      Bakboord 35               9501 JZ Stadskanaal Waterland
# 3  Salviastraat 45             7531 VX Enschede Park Stokhorst
# 4    Emmastraat 29               2665 CR Bleiswijk Oranjebuurt
#
#                 address3_deep                                url_adress3_deep  \
# 0                  Binnenveld                   informatie/rhenen/binnenveld/
# 1  2e Daalsebuurt en omgeving  informatie/utrecht/2e-daalsebuurt-en-omgeving/
# 2                   Waterland               informatie/stadskanaal/waterland/
# 3              Park Stokhorst             informatie/enschede/park-stokhorst/
# 4                 Oranjebuurt               informatie/bleiswijk/oranjebuurt/
#
#                                      highlights_deep        price_deep  \
# 0  Uitgelichte kenmerken\n269 m²\nwonen\n5.120 m²...  € 1.200.000 k.k.
# 1  Uitgelichte kenmerken\n112 m²\nwonen\n77 m²\np...    € 550.000 k.k.
# 2  Uitgelichte kenmerken\n139 m²\nwonen\n465 m²\n...    € 339.000 k.k.
# 3  Uitgelichte kenmerken\n102 m²\nwonen\n141 m²\n...    € 245.000 k.k.
# 4  Uitgelichte kenmerken\n71 m²\nwonen\n143 m²\np...    € 320.000 k.k.
#
#                                      sale_dates_deep  \
# 0  Aangeboden sinds\n16 april 2022\nVerkoopdatum\...
# 1  Aangeboden sinds\n8 april 2022\nVerkoopdatum\n...
# 2  Aangeboden sinds\n8 april 2022\nVerkoopdatum\n...
# 3  Aangeboden sinds\n2 april 2022\nVerkoopdatum\n...
# 4  Aangeboden sinds\n31 maart 2022\nVerkoopdatum\...
#
#                                     description_deep  \
# 0  \nWonen, leven en  genieten  op misschien  wel...
# 1  \nWat een heerlijke  woning!  <br>Zoek jij  ee...
# 2  \nSLAAPKAMER EN BADKAMER  OP  DE BEGANE  GROND...
# 3  \nVerspringende tussenwoning met  eigen  oprit...
# 4  \nKEURIGE TUSSENWONING MET  DIEPE  TUIN OP  HE...
#
#                                      attributes_deep
# 0  Overdracht\nLaatste vraagprijs\n€ 1.200.000 ko...
# 1  Overdracht\nLaatste vraagprijs\n€ 550.000 kost...
# 2  Overdracht\nLaatste vraagprijs\n€ 339.000 kost...
# 3  Overdracht\nLaatste vraagprijs\n€ 245.000 kost...
# 4  Overdracht\nLaatste vraagprijs\n€ 320.000 kost...

# %% [markdown]
# # Opdracht 1: Dataselectie
# 1. Toon het aantal rijen in de dataset ([klik hier voor een hint](./hints/hint_1.1.md)).
# 2. Toon het aantal kolommenin de dataset ([hint](./hints/hint_1.2.md)).
# 3. Toon de rijen 15 tot 20 ([hint](./hints/hint_1.3.md)).
# 4. Toon de kolom `price` in een `series` ([hint](./hints/hint_1.4.md)).
# 5. Toon de kolom `price` in een `DataFrame` ([hint](./hints/hint_1.5.md)).
# 6. Toon de kolommen `price` en `spatial_info` in één `DataFrame` ([hint](./hints/hint_1.6.md)).
# 7. Toon rijen 15 tot 20 van de kolommen `price`, `spatial_info`, `address1` en `address2` in die volgorde in één `DataFrame` ([hint](./hints/hint_1.7.md)).
# 8. Toon rijen 50 tot 55 van de eerste 9 kolommen ([hint](./hints/hint_1.8.md)).

# %% [markdown]
# # Opdracht 2: Eerste visualisatie
# 1. Reproduceer de onderstaande grafiek ([hint](./hints/hint_2.1.md)):
#
# ![Frequentie van de top 10 makelaars](./images/opdracht_2.1.png "Frequentie van de top 10 makelaars")

# %% [markdown]
# # Opdracht 3: Data-extractie en visualisatie van prijzen
# 1. Extraheer de prijzen uit de kolom `price` ([hints](./hints/hint_3.1.md)).
# 2. Geef een histogram weer van de prijzen ([hints](./hints/hint_3.2.md)).
# 3. Geef een boxplot weer van de prijzen ([hints](./hints/hint_3.3.md)).
#
# ![Voorbeeld histogram](./images/opdracht_3.2.png "Voorbeeld histogram")
# ![Voorbeeld boxplot](./images/opdracht_3.3.png "Voorbeeld boxplot")

# %% [markdown]
# # Opdracht 4: Meer extractie en visualisatie
# 1. Extraheer de woonplaatsen en postcodes uit bijvoorbeeld `address2`.
# 2. Maak door middel van een grafiek duidelijk in welke 10 woonplaatsen de meeste huizen zijn verkocht.
# 3. Geef ook weer wat de gemiddeld verkoopprijs was in die 10 woonplaatsen.
# 4. Welke postcode heeft de hoogste gemiddelde verkoopprijs?
# 5. En wat als je alleen de cijfers van de postcode gebruikt?
# 6. Extraheer het woonoppervlak, perceeloppervlak en het aantal kamers uit bijvoorbeeld `spatial_info`.
# 7. Plot `plt.scatter()` plots die de correlatie laten zien tussen de prijs en deze drie nieuwe variabelen.

# %% [markdown]
# # Opdracht 5: Data analyse
# 1. Onderzoek de uitschieters in de prijzen en oppervlakten. Zijn alle verkochte objecten huizen?
# 2. Maak de hiervoor gemaakte visualisaties nogmaals, maar dan gesplitst over de soorten objecten.
